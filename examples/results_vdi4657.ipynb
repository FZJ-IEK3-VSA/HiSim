# %%
import pandas as pd

# %%
df=pd.DataFrame()
for folder in os.listdir('results'):
    try:
        df=pd.concat([df,pd.read_csv(r'results/'+folder+'/results_kpi.csv')])
    except:
        print('No `results_kpi.csv` in ' + folder)
df.sort_values('p_pv')
# Out:
#   electric_loadprofile  weather_region weather_type  weather_year    p_pv  \
# 0             LP_W_EFH               4            a          2015     1.0
# 0             LP_W_EFH               4            a          2015     1.0
# 0             LP_W_EFH               4            a          2015    10.0
# 0             LP_W_EFH               4            a          2015   100.0
# 0             LP_W_EFH               4            a          2015  1000.0
#
#     e_bat  production_sum [kWh]  consumption_sum [kWh]  \
# 0     1.0             942.63025           1.000005e+03
# 0     1.0             942.63025           1.000005e+03
# 0    10.0            9426.30250           1.000006e+04
# 0   100.0           94263.02500           1.000006e+05
# 0  1000.0          942630.25000           1.000006e+06
#
#    battery_discharge [kWh]  battery_charge [kWh]  grid_feed [kWh]  \
# 0               198.704865            356.791541       311.697339
# 0               198.704865            356.791541       311.697339
# 0              2380.826578           2725.209269      3548.109222
# 0             24288.975843          26263.220268     36089.479776
# 0            243499.357542         260528.058281    362632.234713
#
#    grid_supply [kWh]  autarkiegrad  eigenverbrauch
# 0         527.149890      0.472853        0.669332
# 0         527.149890      0.472853        0.669332
# 0        4466.214413      0.553381        0.623595
# 0       43800.994200      0.561992        0.617141
# 0      437033.678393      0.562969        0.615297

# %%
df=pd.DataFrame()
for folder in os.listdir('results'):
    try:
        df=pd.concat([df,pd.read_csv(r'results/'+folder+'/results_kpi.csv')])
    except:
        print('No `results_kpi.csv` in ' + folder)
df.sort_values('p_pv')
# Out:
#   electric_loadprofile  weather_region weather_type  weather_year    p_pv  \
# 0             LP_W_EFH               4            a          2015     1.0
# 0             LP_W_EFH               4            a          2015     1.0
# 0             LP_W_EFH               4            a          2015     1.0
# 0             LP_W_EFH               4            a          2015    10.0
# 0             LP_W_EFH               4            a          2015    10.0
# 0             LP_W_EFH               4            a          2015   100.0
# 0             LP_W_EFH               4            a          2015   100.0
# 0             LP_W_EFH               4            a          2015  1000.0
# 0             LP_W_EFH               4            a          2015  1000.0
#
#     e_bat  production_sum [kWh]  consumption_sum [kWh]  \
# 0     1.0             942.63025           1.000005e+03
# 0     1.0             942.63025           1.000005e+03
# 0     1.0             942.63025           1.000005e+03
# 0    10.0            9426.30250           1.000006e+04
# 0    10.0            9426.30250           1.000006e+04
# 0   100.0           94263.02500           1.000006e+05
# 0   100.0           94263.02500           1.000006e+05
# 0  1000.0          942630.25000           1.000006e+06
# 0  1000.0          942630.25000           1.000006e+06
#
#    battery_discharge [kWh]  battery_charge [kWh]  grid_feed [kWh]  \
# 0               198.704865            356.791541       311.697339
# 0               198.704865            356.791541       311.697339
# 0               202.165442            295.872219       330.248700
# 0              2386.940787           2612.356409      3617.611492
# 0              2380.826578           2725.209269      3548.109222
# 0             24288.975843          26263.220268     36089.479776
# 0             24312.790588          25731.521100     36525.333072
# 0            243592.604538         256904.394306    365619.622120
# 0            243499.357542         260528.058281    362632.234713
#
#    grid_supply [kWh]  autarkiegrad  eigenverbrauch
# 0         527.149890      0.472853        0.669332
# 0         527.149890      0.472853        0.669332
# 0         481.330726      0.518672        0.649652
# 0        4416.779614      0.558324        0.616222
# 0        4466.214413      0.553381        0.623595
# 0       43800.994200      0.561992        0.617141
# 0       43681.588584      0.563187        0.612517
# 0      436306.661888      0.563696        0.612128
# 0      437033.678393      0.562969        0.615297

# %%
import scipy.optimize

# %%
scipy.optimize.optimize._optimize.main()
# Out:
# Nelder-Mead Simplex
# ===================
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 120
#          Function evaluations: 215
# [1.00000328 1.00000565 1.00001091]
#
# Powell Direction Set Method
# ===========================
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 13
#          Function evaluations: 524
# [1. 1. 1.]
#
# Nonlinear CG
# ============
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 43
#          Gradient evaluations: 43
# [1.00000473 1.00000947 1.00001899]
#
# BFGS Quasi-Newton
# =================
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 16
#          Function evaluations: 22
#          Gradient evaluations: 22
# [0.99999999 1.         1.        ]
#
# BFGS approximate gradient
# =========================
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 16
#          Function evaluations: 88
#          Gradient evaluations: 22
# [0.99999731 0.99999462 0.99998924]
#
# Newton-CG with Hessian product
# ==============================
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 17
#          Function evaluations: 25
#          Gradient evaluations: 25
#          Hessian evaluations: 33
# [0.99999957 0.99999913 0.99999826]
#
# Newton-CG with full Hessian
# ===========================
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 17
#          Function evaluations: 25
#          Gradient evaluations: 25
#          Hessian evaluations: 17
# [0.99999957 0.99999913 0.99999826]
#
#
# Minimizing the Rosenbrock function of order 3
#
#  Algorithm 			       Seconds
# ===========			      =========
# Nelder-Mead Simplex	 	 --  0.03303098678588867
# Powell Direction Set Method. 	 --  0.01867365837097168
# Nonlinear CG     	 	 --  0.004796028137207031
# BFGS Quasi-Newton	 	 --  0.005518913269042969
# BFGS without gradient	 	 --  0.006722688674926758
# Newton-CG with hessian product 	 --  0.004972219467163086
# Newton-CG with full Hessian 	 --  0.0067899227142333984
